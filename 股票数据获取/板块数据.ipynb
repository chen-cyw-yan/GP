# %%
import akshare as ak
ak.stock_board_concept_name_ths() 
stock_board_concept_index_ths_df = ak.stock_board_concept_index_ths(symbol="阿里巴巴概念", start_date="20200101", end_date="20250321")
# Out:
# C:\Users\cyw\AppData\Roaming\Python\Python310\site-packages\py_mini_racer\py_mini_racer.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#   0%|          | 0/39 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import akshare as ak
# ----> 2 ak.stock_board_concept_name_ths()
#       3 stock_board_concept_index_ths_df = ak.stock_board_concept_index_ths(symbol="阿里巴巴概念", start_date="20200101", end_date="20250321")
#
# File c:\Users\cyw\.conda\envs\stock\lib\site-packages\akshare\stock_feature\stock_board_concept_ths.py:78, in stock_board_concept_name_ths()
# ...

# %%
stock_board_concept_index_ths_df = ak.stock_board_concept_index_ths(symbol="阿里巴巴概念", start_date="20250205", end_date="20260205")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
stock_board_concept_index_ths_df.head()
# Out:
#            日期       开盘价       最高价       最低价       收盘价          成交量  \
# 0  2025-02-05  1535.855  1561.041  1533.646  1552.184   8093430900
# 1  2025-02-06  1550.446  1600.740  1542.355  1600.565   9493610000
# 2  2025-02-07  1600.399  1658.351  1600.399  1636.052  10980642500
# 3  2025-02-10  1652.914  1705.951  1651.190  1705.951  11050967900
# 4  2025-02-11  1704.662  1725.845  1688.385  1706.186  10589993800
#
#             成交额
# 0  1.320245e+11
# 1  1.536965e+11
# 2  1.852865e+11
# 3  1.792484e+11
# 4  1.733152e+11

# %%
stock_board_concept_index_ths_df['涨幅']=
