# %%
import pandas as pd
df=pd.read_excel('涨停聚焦.xlsx')

# %%
df=df.loc[~df['股票简称'].str.contains('ST')]

# %%
ls=df.columns.to_list()
columns=[]
for i in ls:
    columns=i.split('\n')[0]
df.columns=columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 for i in ls:
#       4     columns=i.split('\n')[0]
# ----> 5 df.columns=columns
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     807 @final
#     808 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     809     """
#     810     This is called from the cython code when we set the `index` attribute
# ...

# %% [markdown]
# ## 题材热力

# %%
dts=[]
for k,v in df.iterrows():
    t=v['涨停原因类别\n2025.06.09'].splitt

# %%
df.head()
# Out:
#         股票代码  股票简称  现价(元)     涨跌幅(%) 首次涨停时间\n2025.06.09 最终涨停时间\n2025.06.09  \
# 2  601059.SH  信达证券  16.04  10.013717           09:42:02           15:00:02
# 3  002250.SZ  联化科技  14.08         10           09:36:33           09:36:33
# 4  600232.SH  金鹰股份      7  10.062893           09:25:00           09:25:00
# 7  002437.SZ  誉衡药业   3.04  10.144928           10:18:21           10:18:21
# 8  002017.SZ  东信和平     12   9.990834           09:31:06           09:31:06
#
#   涨停明细数据\n2025.06.09 连续涨停天数(天)\n2025.06.09 涨停原因类别\n2025.06.09  \
# 2                 --                     1      汇金入主+证券+一季报增长
# 3                 --                     1   氯虫苯甲酰胺中间体+医药CDMO
# 4                 --                     2  注塑机+纺织机械+锂电池+越南投资
# 7                 --                     1   化学制药+细分市场龙头+股份回购
# 8                 --                     1   数字货币+区块链+低空经济+央企
#
#   涨停封单量(股)\n2025.06.09 涨停封单额(元)\n2025.06.09 涨停封成比(%)\n2025.06.09  \
# 2               308868           4954242.72             0.214834
# ...
