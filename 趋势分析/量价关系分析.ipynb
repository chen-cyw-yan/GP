# %%
import akshare as ak

stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="002555", market="sz")
print(stock_individual_fund_flow_df)
# Out:
# C:\Users\cyw\AppData\Roaming\Python\Python310\site-packages\py_mini_racer\py_mini_racer.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#              日期    收盘价   涨跌幅     主力净流入-净额  主力净流入-净占比    超大单净流入-净额  超大单净流入-净占比  \
# 0    2025-08-05  16.76  1.76   47007601.0       3.19  110953233.0        7.53
# 1    2025-08-06  16.98  1.31  -17853749.0      -1.44  -43637397.0       -3.51
# 2    2025-08-07  16.83 -0.88  -67782216.0     -10.60  -43506799.0       -6.80
# 3    2025-08-08  16.55 -1.66  -85323482.0     -11.66  -90655983.0      -12.39
# 4    2025-08-11  16.61  0.36      -2903.0      -0.00   10102595.0        1.90
# ..          ...    ...   ...          ...        ...          ...         ...
# ...

# %%
stock_individual_fund_flow_df.to_excel("zxlx.xlsx")
